# %%
# Task 1: Add your Favorite Food

foods = ["pizza", "burgerr", "pasta"]

# %%
# Add "biryani" to the list.
foods.append("biryani")
foods
# Out:
# ['pizza', 'burgerr', 'pasta', 'biryani']

# %%
# Task 2: Add Multiple Items
colors = ["red", "blue"]
colors.extend(["green", "yellow"])
print(colors)
# Out:
# ['red', 'blue', 'green', 'yellow']

# %%
# Task 3: Insert at specific Position
numbers = [1, 2, 4, 5]
numbers.insert(2, 3)
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Task 4: Remove an Item
fruits = ["apple", "banana", "mango", "grapes"]

# %%
# Remove "mango"
fruits.remove("mango")
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %%
# Task 5: Remove Last Item
items = ["pen", "book", "eraser"]

# Remove the last item
items.pop()
items
# Out:
# ['pen', 'book']

# %%
# Task 6: Find Index
animals = ["cat", "dog", "lion", "tiger"]

# Find the position of "lion"
position_lion = animals.index("lion")
print(position_lion)
# Out:
# 2

# %%
# Task 7: Count Occurrences
nums = [1, 2, 2, 3, 2, 4]

# count how many times 2 appears.
nums = [1, 2, 2, 3, 2, 4]
nums.count(2)
# Out:
# 3

# %%
# Task 8: Sort the List
marks = [85, 45, 90, 60]

# Sort the list in accending order.
marks.sort()
marks
# Out:
# [45, 60, 85, 90]

# %%
# Task 9: Reverse the List
letters = ["a", "b", "c", "d"]

#Reverse the list.
letters.reverse()
letters
# Out:
# ['d', 'c', 'b', 'a']

# %%
# Task 10: Copy the List
original = [10, 20, 30]

#Create a copy of this list into a new variable.
create_copy = original.copy()
create_copy
# Out:
# [10, 20, 30]

# %%
# Task 11: Clear of List
data = [1, 2, 3, 4]

# Remove all elenents from the list.
data.clear()
data
# Out:
# []

# %%
# Task 12: Extend a List
list1 = [1, 2]
list2 = [3, 4]

# Adding all elements of list2 into list1.
list1.extend(list2)
list1
# Out:
# [1, 2, 3, 4]

# %%
#
