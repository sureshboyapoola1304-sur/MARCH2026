# %% [markdown]
# ## Strings

# %%
institute = "Edukron"
focus_area = "Data Science"
tech_stack = "Azure DevOps and Python"

# %%
# 1. Institute name in lowercase
lower_institute = institute.lower()
print(f"1. Lowercase institute: '{lower_institute}'")
# Out:
# 1. Lowercase institute: 'edukron'

# %%
# 2. Focus area in uppercase
upper_focus = focus_area.upper()
print(f"2. Uppercase focus area: '{upper_focus}'")
# Out:
# 2. Uppercase focus area: 'DATA SCIENCE'

# %%
# 3. Tech stack in lowercase
lower_stack = tech_stack.lower()
print(f"3. Lowercase tech stack: '{lower_stack}'")
# Out:
# 3. Lowercase tech stack: 'azure devops and python'

# %%
# 4. Case-insensitive comparison
user_input = "data science"
if user_input.lower() == focus_area.lower():
    print("4. User input matches focus area (case-insensitive).")
# Out:
# 4. User input matches focus area (case-insensitive).

# %%
name = "SURESH"
town = "hindupur"
course = "data science with ai"

# %%
#1 Name in lower case
lower_case = name.lower()
print(f"1. lower_case: {lower_case}")
# Out:
# 1. lower_case: suresh

# %%
#2 Town in upper case
upper_case = town.upper()
print(f"2. upper_case: {upper_case}")
# Out:
# 2. upper_case: HINDUPUR

# %%
#3 Course in Lower Case
lower_case_course = course.lower()
print(f"3. lower_case_course: {lower_case_course}")
# Out:
# 3. lower_case_course: data science with ai

# %%
user_input = "data science"
if user_input.lower() == course.lower():
    print("4. User input matches the course name. (case-insensitive).")
